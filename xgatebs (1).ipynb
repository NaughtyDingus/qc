# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector
import matplotlib.pyplot as plt

qc = QuantumCircuit(1)

qc.x(0)

print("Quantum Circuit:")
print(qc.draw())

state = Statevector.from_instruction(qc)

print("\nState Vector:")
print(state)

plot_bloch_multivector(state)
plt.show()

# %%
qc_d = QuantumCircuit(3, 3)

qc_d.cx(0, 1)
qc_d.cx(1, 2)
qc_d.cx(0, 1)
qc_d.cx(1, 2)

qc_d.measure([0, 1, 2], [0, 1, 2])

print("Circuit (d):")
print(qc_d.draw())

compiled_d = transpile(qc_d, simulator)
result_d = simulator.run(compiled_d, shots=1024).result()
counts_d = result_d.get_counts()

print("Measurement Result (d):", counts_d)
plot_histogram(counts_d)
plt.show()
